# %%
# Tải file về thư mục pretrain_models
# !wget https://paddleocr.bj.bcebos.com/rec_vitstr_none_ce_train.tar -O /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_vitstr_none_ce_train.tar

# Giải nén file trong thư mục pretrain_models
# !tar -xvf /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_vitstr_none_ce_train.tar -C /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/
# Out:
# --2024-12-22 14:45:30--  https://paddleocr.bj.bcebos.com/rec_vitstr_none_ce_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.47.176, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60733440 (58M) [application/x-tar]
# Saving to: ‘/mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_vitstr_none_ce_train.tar’
#
# /mlcv2/WorkingSpace 100%[===================>]  57,92M  17,6MB/s    in 3,9s
#
# 2024-12-22 14:45:36 (14,7 MB/s) - ‘/mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_vitstr_none_ce_train.tar’ saved [60733440/60733440]
#
# rec_vitstr_none_ce_train/
# rec_vitstr_none_ce_train/best_accuracy.states
# rec_vitstr_none_ce_train/train.log
# rec_vitstr_none_ce_train/config.yml
# rec_vitstr_none_ce_train/best_accuracy.pdparams

# %%
cd ../
# Out:
# /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR
# /mlcv2/WorkingSpace/Personal/hamh/miniconda3/envs/paddleocr-2.6.1/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !CUDA_VISIBLE_DEVICES=1 python3 tools/train.py -c configs/ViCalligraphy/rec_vitstr_none_ce.yml

# %%
# !python3 -m paddle.distributed.launch --gpus '1' tools/eval.py -c configs/ViCalligraphy/rec_vitstr_none_ce.yml -o Global.pretrained_model=output/rec/vitstr/best_accuracy
# Out:
# LAUNCH INFO 2025-01-01 17:45:26,062 -----------  Configuration  ----------------------
# [2025-01-01 17:45:26,062] [    INFO] __init__.py:43 - -----------  Configuration  ----------------------
# LAUNCH INFO 2025-01-01 17:45:26,063 auto_parallel_config: None
# [2025-01-01 17:45:26,063] [    INFO] __init__.py:45 - auto_parallel_config: None
# LAUNCH INFO 2025-01-01 17:45:26,063 devices: 1
# [2025-01-01 17:45:26,063] [    INFO] __init__.py:45 - devices: 1
# LAUNCH INFO 2025-01-01 17:45:26,063 elastic_level: -1
# [2025-01-01 17:45:26,063] [    INFO] __init__.py:45 - elastic_level: -1
# LAUNCH INFO 2025-01-01 17:45:26,063 elastic_timeout: 30
# [2025-01-01 17:45:26,063] [    INFO] __init__.py:45 - elastic_timeout: 30
# LAUNCH INFO 2025-01-01 17:45:26,063 gloo_port: 6767
# [2025-01-01 17:45:26,063] [    INFO] __init__.py:45 - gloo_port: 6767
# LAUNCH INFO 2025-01-01 17:45:26,063 host: None
# [2025-01-01 17:45:26,063] [    INFO] __init__.py:45 - host: None
# ...

# %%
# !python3 tools/export_model.py -c configs/ViCalligraphy/rec_vitstr_none_ce.yml -o Global.pretrained_model=output/rec/vitstr/best_accuracy  Global.save_inference_dir=./inference/rec_vitstr
# Out:
# Module name: ViTSTRLabelDecode
# W0105 12:14:18.583621 3970388 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.8
# W0105 12:14:18.584365 3970388 gpu_resources.cc:149] device: 0, cuDNN Version: 90.0.
# [2025/01/05 12:14:18] ppocr INFO: load pretrain successful from output/rec/vitstr/best_accuracy
# I0105 12:14:20.995812 3970388 interpretercore.cc:237] New Executor is Running.
# [2025/01/05 12:14:22] ppocr INFO: inference model is saved to ./inference/rec_vitstr/inference
# [2025/01/05 12:14:22] ppocr INFO: Export inference config file to ./inference/rec_vitstr/inference.yml

# %%
# !python3 tools/infer/predict_rec.py --image_dir='/mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/images/2111.jpg' --rec_model_dir='./inference/rec_vitstr/' --rec_algorithm='ViTSTR' --rec_image_shape='1,224,224' --rec_char_dict_path='./ppocr/utils/dict/vi_vietnam.txt'
# Out:
# Module name: ViTSTRLabelDecode
# [2025/02/05 11:53:23] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/02/05 11:53:25] ppocr INFO: Predicts of /mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/images/2111.jpg:('Ngọn', 0.9996007680892944)

# %%
# !python3 tools/infer/predict_rec_save_dir.py --image_dir='/mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/test_folder_images/images' --rec_model_dir='./inference/rec_vitstr/' --rec_algorithm='ViTSTR' --rec_image_shape='1,224,224' --rec_char_dict_path='./ppocr/utils/dict/vi_vietnam.txt'
# Out:
# Module name: ViTSTRLabelDecode
# [2025/01/05 16:34:32] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# /mlcv2/WorkingSpace/Personal/hamh/miniconda3/envs/paddleocr/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /mlcv2/WorkingSpace/Personal/hamh/miniconda3/envs/paddleocr/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
