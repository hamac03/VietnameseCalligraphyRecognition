# %%
# Di chuyển đến thư mục đích
# !cd /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models

# Tải tệp bằng wget
# !wget https://paddleocr.bj.bcebos.com/PP-OCRv3/chinese/rec_svtr_tiny_none_ctc_en_train.tar

# Giải nén tệp tar
# !tar -xf rec_svtr_tiny_none_ctc_en_train.tar
# Out:
# --2024-12-22 21:28:51--  https://paddleocr.bj.bcebos.com/PP-OCRv3/chinese/rec_svtr_tiny_none_ctc_en_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.47.176, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24135680 (23M) [application/x-tar]
# Saving to: ‘rec_svtr_tiny_none_ctc_en_train.tar’
#
# rec_svtr_tiny_none_ 100%[===================>]  23,02M  7,59MB/s    in 3,0s
#
# 2024-12-22 21:28:55 (7,59 MB/s) - ‘rec_svtr_tiny_none_ctc_en_train.tar’ saved [24135680/24135680]

# %%
cd ../
# Out:
# /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR
# /mlcv2/WorkingSpace/Personal/hamh/miniconda3/envs/paddleocr-2.6.1/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !CUDA_VISIBLE_DEVICES=5 python3 tools/train.py -c configs/ViCalligraphy/rec_svtr_tiny.yml
# Out:
# [2024/12/22 21:34:34] ppocr INFO: Architecture :
# [2024/12/22 21:34:34] ppocr INFO:     Backbone :
# [2024/12/22 21:34:34] ppocr INFO:         depth : [3, 6, 3]
# [2024/12/22 21:34:34] ppocr INFO:         embed_dim : [64, 128, 256]
# [2024/12/22 21:34:34] ppocr INFO:         img_size : [32, 100]
# [2024/12/22 21:34:34] ppocr INFO:         last_stage : True
# [2024/12/22 21:34:34] ppocr INFO:         local_mixer : [[7, 11], [7, 11], [7, 11]]
# [2024/12/22 21:34:34] ppocr INFO:         mixer : ['Local', 'Local', 'Local', 'Local', 'Local', 'Local', 'Global', 'Global', 'Global', 'Global', 'Global', 'Global']
# [2024/12/22 21:34:34] ppocr INFO:         name : SVTRNet
# [2024/12/22 21:34:34] ppocr INFO:         num_heads : [2, 4, 8]
# [2024/12/22 21:34:34] ppocr INFO:         out_channels : 192
# [2024/12/22 21:34:34] ppocr INFO:         out_char_num : 25
# [2024/12/22 21:34:34] ppocr INFO:         patch_merging : Conv
# [2024/12/22 21:34:34] ppocr INFO:         prenorm : False
# ...

# %%
# !python3 -m paddle.distributed.launch --gpus '1' tools/eval.py -c configs/ViCalligraphy/rec_svtr_tiny.yml -o Global.pretrained_model=output/rec/rec_svtr_tiny/best_accuracy
# Out:
# LAUNCH INFO 2024-12-30 12:47:45,822 -----------  Configuration  ----------------------
# [2024-12-30 12:47:45,822] [    INFO] __init__.py:43 - -----------  Configuration  ----------------------
# LAUNCH INFO 2024-12-30 12:47:45,823 auto_parallel_config: None
# [2024-12-30 12:47:45,823] [    INFO] __init__.py:45 - auto_parallel_config: None
# LAUNCH INFO 2024-12-30 12:47:45,823 devices: 1
# [2024-12-30 12:47:45,823] [    INFO] __init__.py:45 - devices: 1
# LAUNCH INFO 2024-12-30 12:47:45,823 elastic_level: -1
# [2024-12-30 12:47:45,823] [    INFO] __init__.py:45 - elastic_level: -1
# LAUNCH INFO 2024-12-30 12:47:45,823 elastic_timeout: 30
# [2024-12-30 12:47:45,823] [    INFO] __init__.py:45 - elastic_timeout: 30
# LAUNCH INFO 2024-12-30 12:47:45,823 gloo_port: 6767
# [2024-12-30 12:47:45,823] [    INFO] __init__.py:45 - gloo_port: 6767
# LAUNCH INFO 2024-12-30 12:47:45,823 host: None
# [2024-12-30 12:47:45,823] [    INFO] __init__.py:45 - host: None
# ...

# %%
# !python3 -m paddle.distributed.launch --gpus '1' tools/eval.py -c configs/ViCalligraphy/rec_svtr_tiny.yml -o Global.pretrained_model=output/rec/rec_svtr_tiny/best_accuracy
# Out:
# LAUNCH INFO 2025-01-01 16:29:22,040 -----------  Configuration  ----------------------
# [2025-01-01 16:29:22,040] [    INFO] __init__.py:43 - -----------  Configuration  ----------------------
# LAUNCH INFO 2025-01-01 16:29:22,040 auto_parallel_config: None
# [2025-01-01 16:29:22,040] [    INFO] __init__.py:45 - auto_parallel_config: None
# LAUNCH INFO 2025-01-01 16:29:22,040 devices: 1
# [2025-01-01 16:29:22,040] [    INFO] __init__.py:45 - devices: 1
# LAUNCH INFO 2025-01-01 16:29:22,040 elastic_level: -1
# [2025-01-01 16:29:22,040] [    INFO] __init__.py:45 - elastic_level: -1
# LAUNCH INFO 2025-01-01 16:29:22,040 elastic_timeout: 30
# [2025-01-01 16:29:22,040] [    INFO] __init__.py:45 - elastic_timeout: 30
# LAUNCH INFO 2025-01-01 16:29:22,040 gloo_port: 6767
# [2025-01-01 16:29:22,040] [    INFO] __init__.py:45 - gloo_port: 6767
# LAUNCH INFO 2025-01-01 16:29:22,040 host: None
# [2025-01-01 16:29:22,040] [    INFO] __init__.py:45 - host: None
# ...

# %%
# !python3 tools/infer_rec.py -c configs/ViCalligraphy/rec_svtr_tiny.yml -o  Global.pretrained_model=output/rec/rec_svtr_tiny/best_accuracy
# Out:
# [2025/01/05 12:30:04] ppocr INFO: Architecture :
# [2025/01/05 12:30:04] ppocr INFO:     Backbone :
# [2025/01/05 12:30:04] ppocr INFO:         depth : [3, 6, 3]
# [2025/01/05 12:30:04] ppocr INFO:         embed_dim : [64, 128, 256]
# [2025/01/05 12:30:04] ppocr INFO:         img_size : [32, 100]
# [2025/01/05 12:30:04] ppocr INFO:         last_stage : True
# [2025/01/05 12:30:04] ppocr INFO:         local_mixer : [[7, 11], [7, 11], [7, 11]]
# [2025/01/05 12:30:04] ppocr INFO:         mixer : ['Local', 'Local', 'Local', 'Local', 'Local', 'Local', 'Global', 'Global', 'Global', 'Global', 'Global', 'Global']
# [2025/01/05 12:30:04] ppocr INFO:         name : SVTRNet
# [2025/01/05 12:30:04] ppocr INFO:         num_heads : [2, 4, 8]
# [2025/01/05 12:30:04] ppocr INFO:         out_channels : 192
# [2025/01/05 12:30:04] ppocr INFO:         out_char_num : 25
# [2025/01/05 12:30:04] ppocr INFO:         patch_merging : Conv
# [2025/01/05 12:30:04] ppocr INFO:         prenorm : False
# ...

# %%
#export model
# !python3 tools/export_model.py -c /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/configs/rec/rec_svtrnet.yml -o Global.pretrained_model=output/rec/rec_svtr_tiny/best_accuracy  Global.save_inference_dir=./inference/rec_svtr_tiny_stn_en
# Out:
# Module name: CTCLabelDecode
# W0105 13:09:41.485132 4071757 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.8
# W0105 13:09:41.485970 4071757 gpu_resources.cc:149] device: 0, cuDNN Version: 90.0.
# [2025/01/05 13:09:42] ppocr INFO: resume from ./output/rec/rec_svtr_tiny/best_accuracy
# I0105 13:09:44.829975 4071757 interpretercore.cc:237] New Executor is Running.
# [2025/01/05 13:09:46] ppocr INFO: inference model is saved to ./inference/rec_svtr_tiny_stn_en/inference
# [2025/01/05 13:09:46] ppocr INFO: Export inference config file to ./inference/rec_svtr_tiny_stn_en/inference.yml

# %%
# !python3 tools/infer/predict_rec.py --image_dir='/mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/images/2111.jpg'  --rec_model_dir='./inference/rec_svtr_tiny_stn_en/' --rec_algorithm='SVTR' --rec_image_shape='3,64,256' --rec_char_dict_path='./ppocr/utils/dict/vi_vietnam.txt'
# Out:
# Module name: CTCLabelDecode
# [2025/02/05 11:52:17] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/02/05 11:52:20] ppocr INFO: Predicts of /mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/images/2111.jpg:('Ngọn', 0.9993938207626343)

# %%
# !python3 tools/infer/predict_rec_save_dir.py --image_dir='/mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/test_folder_images/images'  --rec_model_dir='./inference/rec_svtr_tiny_stn_en/' --rec_algorithm='SVTR' --rec_image_shape='3,64,256' --rec_char_dict_path='./ppocr/utils/dict/vi_vietnam.txt'
# Out:
# Module name: CTCLabelDecode
# [2025/01/05 16:33:03] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
