# %%
# !wget https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/rec_r50_vd_srn_train.tar -O /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_r50_vd_srn_train.tar
# !tar -xvf /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_r50_vd_srn_train.tar -C /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/
# Out:
# --2024-12-22 14:30:15--  https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/rec_r50_vd_srn_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.47.176, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 954112000 (910M) [application/x-tar]
# Saving to: ‘/mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_r50_vd_srn_train.tar’
#
# /mlcv2/WorkingSpace 100%[===================>] 909,91M  30,6MB/s    in 38s
#
# 2024-12-22 14:30:54 (24,1 MB/s) - ‘/mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_r50_vd_srn_train.tar’ saved [954112000/954112000]
#
# rec_r50_vd_srn_train/
# rec_r50_vd_srn_train/best_accuracy.states
# rec_r50_vd_srn_train/best_accuracy.pdparams
# rec_r50_vd_srn_train/best_accuracy.pdopt

# %%
cd ../
# Out:
# /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR
# /mlcv2/WorkingSpace/Personal/hamh/miniconda3/envs/paddleocr/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !CUDA_VISIBLE_DEVICES=6 python3 tools/train.py -c configs/ViCalligraphy/rec_r50_fpn_srn.yml

# %%
# !python3 -m paddle.distributed.launch --gpus '5' tools/eval.py -c configs/ViCalligraphy/rec_r50_fpn_srn.yml -o Global.pretrained_model=output/rec/srn/best_accuracy
# Out:
# LAUNCH INFO 2024-12-31 10:53:52,358 -----------  Configuration  ----------------------
# [2024-12-31 10:53:52,358] [    INFO] __init__.py:43 - -----------  Configuration  ----------------------
# LAUNCH INFO 2024-12-31 10:53:52,358 auto_parallel_config: None
# [2024-12-31 10:53:52,358] [    INFO] __init__.py:45 - auto_parallel_config: None
# LAUNCH INFO 2024-12-31 10:53:52,358 devices: 5
# [2024-12-31 10:53:52,358] [    INFO] __init__.py:45 - devices: 5
# LAUNCH INFO 2024-12-31 10:53:52,358 elastic_level: -1
# [2024-12-31 10:53:52,358] [    INFO] __init__.py:45 - elastic_level: -1
# LAUNCH INFO 2024-12-31 10:53:52,358 elastic_timeout: 30
# [2024-12-31 10:53:52,358] [    INFO] __init__.py:45 - elastic_timeout: 30
# LAUNCH INFO 2024-12-31 10:53:52,358 gloo_port: 6767
# [2024-12-31 10:53:52,358] [    INFO] __init__.py:45 - gloo_port: 6767
# LAUNCH INFO 2024-12-31 10:53:52,358 host: None
# [2024-12-31 10:53:52,358] [    INFO] __init__.py:45 - host: None
# ...

# %%
# !python3 tools/export_model.py -c configs/ViCalligraphy/rec_r50_fpn_srn.yml -o Global.pretrained_model=output/rec/srn/best_accuracy  Global.save_inference_dir=./inference/rec_srn
# Out:
# Module name: SRNLabelDecode
# W0101 16:01:50.551009 853947 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.8
# W0101 16:01:50.551975 853947 gpu_resources.cc:149] device: 0, cuDNN Version: 90.0.
# [2025/01/01 16:01:51] ppocr INFO: load pretrain successful from output/rec/srn/best_accuracy
# I0101 16:01:56.247119 853947 interpretercore.cc:237] New Executor is Running.
# [2025/01/01 16:02:03] ppocr INFO: inference model is saved to ./inference/rec_srn/inference
# [2025/01/01 16:02:03] ppocr INFO: Export inference config file to ./inference/rec_srn/inference.yml

# %%
# !python3 tools/infer/predict_rec_save_dir.py --image_dir="/mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/test_folder_images/images" --rec_model_dir="./inference/rec_srn/" --rec_image_shape="1,64,256" --rec_algorithm="SRN" --rec_char_dict_path="ppocr/utils/dict/vi_vietnam.txt" --use_space_char=False
# Out:
# Module name: SRNLabelDecode
# [2025/01/05 16:33:08] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
