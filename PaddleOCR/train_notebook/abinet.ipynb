# %%
# !wget https://paddleocr.bj.bcebos.com/rec_r45_abinet_train.tar -O /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_r45_abinet_train.tar
# !tar -xvf /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_r45_abinet_train.tar -C /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/
# Out:
# --2024-12-22 12:07:20--  https://paddleocr.bj.bcebos.com/rec_r45_abinet_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.47.176, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 307732480 (293M) [application/x-tar]
# Saving to: ‘/mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_r45_abinet_train.tar’
#
# /mlcv2/WorkingSpace 100%[===================>] 293,48M  25,5MB/s    in 11s
#
# 2024-12-22 12:07:32 (25,6 MB/s) - ‘/mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR/pretrain_models/rec_r45_abinet_train.tar’ saved [307732480/307732480]
#
# rec_r45_abinet_train/
# rec_r45_abinet_train/best_accuracy.states
# rec_r45_abinet_train/train.log
# rec_r45_abinet_train/abinet_vl_pretrained.pdparams
# rec_r45_abinet_train/config.yml
# rec_r45_abinet_train/best_accuracy.pdparams

# %%
cd ../
# Out:
# /mlcv2/WorkingSpace/Personal/hamh/Ha/Methods/PaddleOCR
# /mlcv2/WorkingSpace/Personal/hamh/miniconda3/envs/paddleocr/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !CUDA_VISIBLE_DEVICES=5 python3 tools/train.py -c configs/ViCalligraphy/rec_r45_abinet.yml
# Out:
# [2024/12/22 13:06:04] ppocr WARNING: You are using VisualDL, the VisualDL is deprecated and removed in ppocr!
# [2024/12/22 13:06:04] ppocr INFO: Architecture :
# [2024/12/22 13:06:04] ppocr INFO:     Backbone :
# [2024/12/22 13:06:04] ppocr INFO:         name : ResNet45
# [2024/12/22 13:06:04] ppocr INFO:     Head :
# [2024/12/22 13:06:04] ppocr INFO:         image_size : [32, 128]
# [2024/12/22 13:06:04] ppocr INFO:         iter_size : 3
# [2024/12/22 13:06:04] ppocr INFO:         max_length : 25
# [2024/12/22 13:06:04] ppocr INFO:         name : ABINetHead
# [2024/12/22 13:06:04] ppocr INFO:         use_lang : True
# [2024/12/22 13:06:04] ppocr INFO:     Transform : None
# [2024/12/22 13:06:04] ppocr INFO:     algorithm : ABINet
# [2024/12/22 13:06:04] ppocr INFO:     in_channels : 3
# [2024/12/22 13:06:04] ppocr INFO:     model_type : rec
# [2024/12/22 13:06:04] ppocr INFO: Eval :
# [2024/12/22 13:06:04] ppocr INFO:     dataset :
# ...

# %%
# !python3 -m paddle.distributed.launch --gpus '6' tools/eval.py -c configs/ViCalligraphy/rec_r45_abinet.yml -o Global.pretrained_model=output/rec/r45_abinet_new/best_accuracy
# Out:
# LAUNCH INFO 2024-12-30 12:44:18,095 -----------  Configuration  ----------------------
# [2024-12-30 12:44:18,095] [    INFO] __init__.py:43 - -----------  Configuration  ----------------------
# LAUNCH INFO 2024-12-30 12:44:18,095 auto_parallel_config: None
# [2024-12-30 12:44:18,095] [    INFO] __init__.py:45 - auto_parallel_config: None
# LAUNCH INFO 2024-12-30 12:44:18,095 devices: 6
# [2024-12-30 12:44:18,095] [    INFO] __init__.py:45 - devices: 6
# LAUNCH INFO 2024-12-30 12:44:18,095 elastic_level: -1
# [2024-12-30 12:44:18,095] [    INFO] __init__.py:45 - elastic_level: -1
# LAUNCH INFO 2024-12-30 12:44:18,096 elastic_timeout: 30
# [2024-12-30 12:44:18,096] [    INFO] __init__.py:45 - elastic_timeout: 30
# LAUNCH INFO 2024-12-30 12:44:18,096 gloo_port: 6767
# [2024-12-30 12:44:18,096] [    INFO] __init__.py:45 - gloo_port: 6767
# LAUNCH INFO 2024-12-30 12:44:18,096 host: None
# [2024-12-30 12:44:18,096] [    INFO] __init__.py:45 - host: None
# ...

# %%
# !python3 -m paddle.distributed.launch --gpus '0' tools/eval.py -c configs/ViCalligraphy/rec_r45_abinet.yml -o Global.pretrained_model=output/rec/r45_abinet_new/best_accuracy
# Out:
# LAUNCH INFO 2024-12-30 12:26:10,251 -----------  Configuration  ----------------------
# [2024-12-30 12:26:10,251] [    INFO] __init__.py:43 - -----------  Configuration  ----------------------
# LAUNCH INFO 2024-12-30 12:26:10,252 auto_parallel_config: None
# [2024-12-30 12:26:10,252] [    INFO] __init__.py:45 - auto_parallel_config: None
# LAUNCH INFO 2024-12-30 12:26:10,252 devices: 0
# [2024-12-30 12:26:10,252] [    INFO] __init__.py:45 - devices: 0
# LAUNCH INFO 2024-12-30 12:26:10,252 elastic_level: -1
# [2024-12-30 12:26:10,252] [    INFO] __init__.py:45 - elastic_level: -1
# LAUNCH INFO 2024-12-30 12:26:10,252 elastic_timeout: 30
# [2024-12-30 12:26:10,252] [    INFO] __init__.py:45 - elastic_timeout: 30
# LAUNCH INFO 2024-12-30 12:26:10,252 gloo_port: 6767
# [2024-12-30 12:26:10,252] [    INFO] __init__.py:45 - gloo_port: 6767
# LAUNCH INFO 2024-12-30 12:26:10,252 host: None
# [2024-12-30 12:26:10,252] [    INFO] __init__.py:45 - host: None
# ...

# %%
# !python3 -m paddle.distributed.launch --gpus '0' tools/eval.py -c configs/ViCalligraphy/rec_r45_abinet.yml -o Global.pretrained_model=output/rec/r45_abinet_new/best_accuracy
# Out:
# LAUNCH INFO 2024-12-31 10:49:22,274 -----------  Configuration  ----------------------
# [2024-12-31 10:49:22,274] [    INFO] __init__.py:43 - -----------  Configuration  ----------------------
# LAUNCH INFO 2024-12-31 10:49:22,274 auto_parallel_config: None
# [2024-12-31 10:49:22,274] [    INFO] __init__.py:45 - auto_parallel_config: None
# LAUNCH INFO 2024-12-31 10:49:22,274 devices: 0
# [2024-12-31 10:49:22,274] [    INFO] __init__.py:45 - devices: 0
# LAUNCH INFO 2024-12-31 10:49:22,274 elastic_level: -1
# [2024-12-31 10:49:22,274] [    INFO] __init__.py:45 - elastic_level: -1
# LAUNCH INFO 2024-12-31 10:49:22,274 elastic_timeout: 30
# [2024-12-31 10:49:22,274] [    INFO] __init__.py:45 - elastic_timeout: 30
# LAUNCH INFO 2024-12-31 10:49:22,274 gloo_port: 6767
# [2024-12-31 10:49:22,274] [    INFO] __init__.py:45 - gloo_port: 6767
# LAUNCH INFO 2024-12-31 10:49:22,274 host: None
# [2024-12-31 10:49:22,274] [    INFO] __init__.py:45 - host: None
# ...

# %%
# !python3 tools/export_model.py -c configs/ViCalligraphy/rec_r45_abinet.yml -o Global.pretrained_model=output/rec/r45_abinet_new/best_accuracy  Global.save_inference_dir=./inference/rec_r45_abinet
# Out:
# Module name: ABINetLabelDecode
# W0101 15:58:00.423218 846792 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.8
# W0101 15:58:00.424180 846792 gpu_resources.cc:149] device: 0, cuDNN Version: 90.0.
# [2025/01/01 15:58:01] ppocr INFO: load pretrain successful from output/rec/r45_abinet_new/best_accuracy
# I0101 15:58:07.199715 846792 interpretercore.cc:237] New Executor is Running.
# [2025/01/01 15:58:13] ppocr INFO: inference model is saved to ./inference/rec_r45_abinet/inference
# [2025/01/01 15:58:13] ppocr INFO: Export inference config file to ./inference/rec_r45_abinet/inference.yml

# %%
# !python3 tools/infer/predict_rec.py --image_dir="/mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/images/2111.jpg" --rec_model_dir='./inference/rec_r45_abinet/' --rec_algorithm='ABINet' --rec_image_shape='3,32,128' --rec_char_dict_path="./ppocr/utils/dict/vi_vietnam.txt"
# Out:
# Module name: ABINetLabelDecode
# [2025/01/01 16:04:42] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/01/01 16:04:47] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# [2025/01/01 16:04:47] ppocr INFO: Predicts of /mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/images/2111.jpg:('Ngọn', 0.9997026920318604)

# %%
# Lưu kết quả tập test
# !python3 tools/infer/predict_rec_save_dir.py --image_dir="/mlcv2/WorkingSpace/Personal/hamh/Ha/Data/Vicalligraphy/ViCalligraphy/test_folder_images/images" --rec_model_dir='./inference/rec_r45_abinet/' --rec_algorithm='ABINet' --rec_image_shape='3,32,128' --rec_char_dict_path="./ppocr/utils/dict/vi_vietnam.txt"
# Out:
# Module name: ABINetLabelDecode
# [2025/01/05 16:33:36] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
